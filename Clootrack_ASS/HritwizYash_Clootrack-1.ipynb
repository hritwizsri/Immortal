# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Data Analyst - Test Data.xlsx')

# %%
data
# Out:
#                                                  Review       date  \
# 0     I was very impressed with the resort.\n Great ... 2019-08-20
# 1     The rooms were nice the outside needs work als... 2019-08-20
# 2     Great location! I have stayed at this hotel on... 2019-08-20
# 3     The hotel was adequate for my stay. The strips... 2019-08-20
# 4     Great location, room was large and spacious. P... 2019-08-19
# ...                                                 ...        ...
# 6443  ·the staff were all so friendly. frank, the ch... 2019-07-12
# 6444         ·the internet barely worked or didn't work 2019-07-12
# 6445  ·the location was great.\n \n \n \n \n ·the be... 2019-07-10
# 6446  ·we were early for check in and the staff was ... 2019-07-10
# 6447  ·staff, free coffee, location and activities.\... 2019-07-10
#
#                       Location
# 0                    Sebastian
# 1                  Los Angeles
# 2                      Georgia
# 3                          NaN
# ...

# %%
data.describe()
# Out:
# <ipython-input-4-2bb0b18689d4>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe()
#                                        Review                 date  \
# count                                    6393                 6448
# unique                                   6384                  385
# top     Amazing\n  \n  Read more\n  Read less  2019-06-01 00:00:00
# freq                                        4                  150
# first                                     NaN  2018-08-01 00:00:00
# last                                      NaN  2019-08-20 00:00:00
#
#                         Location
# count                       1711
# unique                      1082
# top     United States of America
# freq                         116
# ...

# %% [markdown]
# ### Review Column Contains 6384 Unique value out of 6393
# ### Date Column Contains 385 Unique value out of 6448
# ### Location Column Contains 1082 Unique value out of 1711

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6448 entries, 0 to 6447
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review    6393 non-null   object
#  1   date      6448 non-null   datetime64[ns]
#  2   Location  1711 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 151.2+ KB

# %%
data.isna().sum()
# Out:
# Review        55
# date           0
# Location    4737
# dtype: int64

# %% [markdown]
# ## Location column contains lots of null values
# ### Here, We have two options in this type of  scenarios i.e. delete all null rows or fill null values using Location's     Mode

# %%
data['Location'].mode()
# Out:
# 0    United States of America
# dtype: object

# %% [markdown]
# ### I am choosing to delete all null values in Location Column

# %%
#remove all the null values 
data=data.dropna(subset=["Location"])

# %%
data.isna().sum()
# Out:
# Review      6
# date        0
# Location    0
# dtype: int64

# %%
# pd.set_option('max_row',None)
data['Location'].value_counts()
# Out:
# United States of America    116
# New York                     34
# San Jose                     19
# California                   19
# Canada                       16
#                            ...
# Williamston, NC               1
# Surrey UK                     1
# Palm Springs                  1
# Silicon Valley San Jose       1
# Orlando Fl                    1
# Name: Location, Length: 1082, dtype: int64

# %% [markdown]
# ### Encodeing location names having  frequency greater than equals 4 with its actual Country name

# %%
data['Location']=data['Location'].str.replace('New York','United States of America')
data['Location']=data['Location'].str.replace('Florida','United States of America')
data['Location']=data['Location'].str.replace('San Jose','United States of America')
data['Location']=data['Location'].str.replace('California','United States of America')
data['Location']=data['Location'].str.replace('New York, NY','United States of America')
data['Location']=data['Location'].str.replace('Orlando','United States of America')
data['Location']=data['Location'].str.replace('NY','United States of America')
data['Location']=data['Location'].str.replace('Miami','United States of America')
data['Location']=data['Location'].str.replace('San Diego','United States of America')
data['Location']=data['Location'].str.replace('Los Angeles','United States of America')
data['Location']=data['Location'].str.replace('Seattle','United States of America')
data['Location']=data['Location'].str.replace('Washington, DC','United States of America')
data['Location']=data['Location'].str.replace('Philadelphia','United States of America')
data['Location']=data['Location'].str.replace('Boston','United States of America')
data['Location']=data['Location'].str.replace('NYC','United States of America')
data['Location']=data['Location'].str.replace('San Francisco','United States of America')
data['Location']=data['Location'].str.replace('Tampa','United States of America')
data['Location']=data['Location'].str.replace('Boston','United States of America')
data['Location']=data['Location'].str.replace('Michigan','United States of America')
data['Location']=data['Location'].str.replace('Chicago','United States of America')
data['Location']=data['Location'].str.replace('New Jersey','United States of America')
data['Location']=data['Location'].str.replace('United States of America, CA ','United States of America')
data['Location']=data['Location'].str.replace('Maryland','United States of America')
data['Location']=data['Location'].str.replace('United States of America, United States of America','United States of America')
data['Location']=data['Location'].str.replace('United States of America, FL','United States of America')
data['Location']=data['Location'].str.replace('United States of AmericaC','United States of America')
data['Location']=data['Location'].str.replace('Puerto Rico','United States of America')
data['Location']=data['Location'].str.replace('United States of America, CA','United States of America')
data['Location']=data['Location'].str.replace('United States of America, WA','United States of America')
data['Location']=data['Location'].str.replace('Long Island, United States of America ','United States of America')
data['Location']=data['Location'].str.replace('Jacksonville','United States of America')
data['Location']=data['Location'].str.replace('Texas','United States of America')
data['Location']=data['Location'].str.replace('United States of America, fl','United States of America')
data['Location']=data['Location'].str.replace('United States of America, us','United States of America')
data['Location']=data['Location'].str.replace('Atlanta, GA','United States of America')
data['Location']=data['Location'].str.replace('Pennsylvania','United States of America')
data['Location']=data['Location'].str.replace('CA','United States of America')
data['Location']=data['Location'].str.replace('United States of America, United States of America','United States of America')
data['Location']=data['Location'].str.replace('NC','United States of America')
data['Location']=data['Location'].str.replace('Long Island, United States of America','United States of America')
data['Location']=data['Location'].str.replace('Fresh Meadows, United States of America','United States of America')
data['Location']=data['Location'].str.replace('United States of America United States of America','United States of America')

data['Location']=data['Location'].str.replace('Virginia','United States of America')
data['Location']=data['Location'].str.replace('Washington DC','United States of America')
data['Location']=data['Location'].str.replace('Sacramento','United States of America')
data['Location']=data['Location'].str.replace('Irvine','United States of America')
data['Location']=data['Location'].str.replace('Fresno, United States of America','United States of America')
data['Location']=data['Location'].str.replace('DC','United States of America')
data['Location']=data['Location'].str.replace('Illinois','United States of America')
data['Location']=data['Location'].str.replace('United States of America FL','United States of America')
data['Location']=data['Location'].str.replace('Las Vegas','United States of America')
data['Location']=data['Location'].str.replace('Las Vegas, NV','United States of America')
data['Location']=data['Location'].str.replace('London','United Kingdom')
data['Location']=data['Location'].str.replace('England','United Kingdom')
data['Location']=data['Location'].str.replace('Vancouver, BC','Canada')
data['Location']=data['Location'].str.replace('Montreal','Canada')
data['Location']=data['Location'].str.replace('Toronto','Canada')
data['Location']=data['Location'].str.replace('Vancouver','Canada')
data['Location']=data['Location'].str.replace('Canada, Canada','Canada')
# Out:
# <ipython-input-21-25176befe035>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Location']=data['Location'].str.replace('New York','United States of America')
# <ipython-input-21-25176befe035>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Location']=data['Location'].str.replace('Florida','United States of America')
# <ipython-input-21-25176befe035>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data['Location'].value_counts()
# Out:
# United States of America    515
# Canada                       46
# United Kingdom               25
# Singapore                     6
# Guadalajara                   4
#                            ...
# Queens, ny                    1
# Palm Beach, us                1
# lakewood, oh                  1
# Warren, RI                    1
# irvine                        1
# Name: Location, Length: 985, dtype: int64

# %% [markdown]
# #### Top 3 Countries having mejority Reviews
# ####  United States of America , Canada , United Kingdom

# %%
plt.figure(figsize=(8,8))
plt.pie(data['Location'].value_counts(),autopct='%.1f')


plt.title("Review_Location")
plt.show()

# %%
data['DaysOfWeek']=data['date'].dt.day_name()
# Out:
# <ipython-input-24-b302b161083c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DaysOfWeek']=data['date'].dt.day_name()

# %%
data
# Out:
#                                                  Review       date  \
# 0     I was very impressed with the resort.\n Great ... 2019-08-20
# 1     The rooms were nice the outside needs work als... 2019-08-20
# 2     Great location! I have stayed at this hotel on... 2019-08-20
# 4     Great location, room was large and spacious. P... 2019-08-19
# 10    Very clean and friendly and I love the locatio... 2019-08-19
# ...                                                 ...        ...
# 6443  ·the staff were all so friendly. frank, the ch... 2019-07-12
# 6444         ·the internet barely worked or didn't work 2019-07-12
# 6445  ·the location was great.\n \n \n \n \n ·the be... 2019-07-10
# 6446  ·we were early for check in and the staff was ... 2019-07-10
# 6447  ·staff, free coffee, location and activities.\... 2019-07-10
#
#                       Location DaysOfWeek
# 0                    Sebastian    Tuesday
# 1     United States of America    Tuesday
# ...

# %%
plt.figure(figsize=(8,8))
plt.pie(data['DaysOfWeek'].value_counts(),labels=["Monday","Tuesday","Sunday","Wednesday","Saturday","Friday","Thursday"],autopct='%.1f')


plt.title("Most_Reviewed_Days")
plt.show()

# %% [markdown]
# ### On Monday People  Reviewed Most

# %%
data['date'].min()
# Out:
# Timestamp('2018-08-02 00:00:00')

# %%
data['date'].max()
# Out:
# Timestamp('2019-08-20 00:00:00')

# %%
Timedelta=data['date'].max()-data['date'].min()

# %%
Timedelta
# Out:
# Timedelta('383 days 00:00:00')

# %% [markdown]
# ### Data contains 383 days reviews
